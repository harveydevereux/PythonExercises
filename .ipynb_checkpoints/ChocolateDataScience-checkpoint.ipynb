# %%
import numpy as np # mathematics
import pandas as pd # data frames,csv, etc
import matplotlib.pyplot as plt
import sklearn # models (scikit-learn https://scikit-learn.org/stable/)
import seaborn

# %% [markdown]
# We are going to examine the ratings of various Chocolate bars
# to learn a little about Data Science.
#
# The dataset comes from Kaggle, an online platform for data science
# competitions (https://www.kaggle.com/rtatman/chocolate-bar-ratings).
#
# The context for our dataset is given below.
#
# #### Context
#
# Chocolate is one of the most popular candies in the world. Each year, residents of the United States collectively eat more than 2.8 billions pounds. However, not all chocolate bars are created equal! This dataset contains expert ratings of over 1,700 individual chocolate bars, along with information on their regional origin, percentage of cocoa, the variety of chocolate bean used and where the beans were grown.
# Flavors of Cacao Rating System:
#
#     5= Elite (Transcending beyond the ordinary limits)
#     4= Premium (Superior flavor development, character and style)
#     3= Satisfactory(3.0) to praiseworthy(3.75) (well made with special qualities)
#     2= Disappointing (Passable but contains at least one significant flaw)
#     1= Unpleasant (mostly unpalatable)
#
# Each chocolate is evaluated from a combination of both objective qualities and subjective interpretation. A rating here only represents an experience with one bar from one batch. Batch numbers, vintages and review dates are included in the database when known.
#
# The database is narrowly focused on plain dark chocolate with an aim of appreciating the flavors of the cacao when made into chocolate. The ratings do not reflect health benefits, social missions, or organic status.
#
# Flavor is the most important component of the Flavors of Cacao ratings. Diversity, balance, intensity and purity of flavors are all considered. It is possible for a straight forward single note chocolate to rate as high as a complex flavor profile that changes throughout. Genetics, terroir, post harvest techniques, processing and storage can all be discussed when considering the flavor component.
#
# Texture has a great impact on the overall experience and it is also possible for texture related issues to impact flavor. It is a good way to evaluate the makers vision, attention to detail and level of proficiency.
#
# Aftermelt is the experience after the chocolate has melted. Higher quality chocolate will linger and be long lasting and enjoyable. Since the aftermelt is the last impression you get from the chocolate, it receives equal importance in the overall rating.
#
# Overall Opinion is really where the ratings reflect a subjective opinion. Ideally it is my evaluation of whether or not the components above worked together and an opinion on the flavor development, character and style. It is also here where each chocolate can usually be summarized by the most prominent impressions that you would remember about each chocolate.
#
# #### Goal
#
# We want to explore this data and see what we can learn about chocolate rating!
#
# To do this we will learn how to
# - Import and manipulate raw data using ```Pandas```. (Data Munging)
# - Explore and plot data using ```Pyplot```. (Data Visualisation)
# - Examine basic statistics to inform modelling.
# - Learn about some basic models in ```Scikit-Learn```.
# - Train/fit some models. (Machine Learning).
# - Validate, test, and improve our models by *developing* the data. (Feature Engineering).

# %% [markdown]
# ### The Data
#
# By openning the CSV file *flavors_of_cacao.csv* you can inspect the
# columns, they are
#
# Company  (Maker-if known)
#
# Name of the company manufacturing the bar.
# Specific Bean Origin or Bar Name
#
# The specific geo-region of origin for the bar.
#
# REF
# A value linked to when the review was entered in the database. Higher = more recent.
# Review Date
#
# Date of publication of the review.
# Cocoa Percent
#
# Cocoa percentage (darkness) of the chocolate bar being reviewed.
# Company Location
#
# Manufacturer base country.
# Rating
#
# Expert rating for the bar.
# Bean Type
#
# The variety (breed) of bean used, if provided.
# Broad Bean Origin
#
# The broad geo-region of origin for the bean.
#
# ### Getting the data into Python
#
# For this data set we will use the Pandas package in Python as an overview the pandas website
# has a [tutorial of functionality available](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html)
# which you can refer to along with this notebook if you wish. We won't follow here.
#
# We can use the ```read_csv``` function in pandas to open a csv file as below. Use
# the print out to inspect the data set a little.

# %%
Data = pd.read_csv("Chocolate/flavors_of_cacao.csv")
Data
# Out:
#      Company \n(Maker-if known)   Specific Bean Origin\nor Bar Name     REF  \
# 0                      A. Morin                         Agua Grande     NaN
# 1                      A. Morin                               Kpime  1676.0
# 2                      A. Morin                              Atsane  1676.0
# 3                      A. Morin                               Akata  1680.0
# 4                      A. Morin                              Quilla  1704.0
# 5                      A. Morin                            Carenero  1315.0
# 6                      A. Morin                                Cuba  1315.0
# 7                      A. Morin                        Sur del Lago  1315.0
# 8                      A. Morin                      Puerto Cabello  1319.0
# 9                      A. Morin                             Pablino  1319.0
# 10                     A. Morin                              Panama  1011.0
# 11                     A. Morin                          Madagascar  1011.0
# 12                     A. Morin                              Brazil  1011.0
# 13                     A. Morin                            Equateur  1011.0
# 14                     A. Morin                            Colombie  1015.0
# 15                     A. Morin                            Birmanie  1015.0
# 16                     A. Morin                    Papua New Guinea  1015.0
# 17                     A. Morin                               Chuao  1015.0
# 18                     A. Morin                               Piura  1019.0
# 19                     A. Morin                Chanchamayo Province  1019.0
# 20                     A. Morin                Chanchamayo Province  1019.0
# 21                     A. Morin                             Bolivia   797.0
# 22                     A. Morin                                Peru   797.0
# 23                       Acalli             Chulucanas, El Platanal  1462.0
# 24                       Acalli                   Tumbes, Norandino  1470.0
# 25                          Adi                          Vanua Levu   705.0
# 26                          Adi                  Vanua Levu, Toto-A   705.0
# 27                          Adi                          Vanua Levu   705.0
# 28                          Adi              Vanua Levu, Ami-Ami-CA   705.0
# 29           Aequare (Gianduja)           Los Rios, Quevedo, Arriba   370.0
# ...                         ...                                 ...     ...
# 1765                      Zak's                     Belize, Batch 2  1578.0
# 1766                      Zak's                House Blend, Batch 2  1582.0
# 1767              Zart Pralinen                  Millot P., Ambanja  1820.0
# 1768              Zart Pralinen                             UNOCACE  1824.0
# 1769              Zart Pralinen                     San Juan Estate  1824.0
# 1770              Zart Pralinen      Kakao Kamili, Kilombero Valley  1824.0
# 1771              Zart Pralinen      Kakao Kamili, Kilombero Valley  1824.0
# 1772              Zart Pralinen         San Juan Estate, Gran Couva  1880.0
# 1773                     Zokoko                         Guadalcanal  1716.0
# 1774                     Zokoko                       Goddess Blend  1780.0
# 1775                     Zokoko                           Alto Beni   697.0
# 1776                     Zokoko                             Tokiala   701.0
# 1777                     Zokoko                Tranquilidad, Baures   701.0
# 1778                     Zotter                                 Raw  1205.0
# 1779                     Zotter        Bocas del Toro, Cocabo Co-op   801.0
# 1780                     Zotter                     Amazonas Frucht   801.0
# 1781                     Zotter   Satipo Pangoa region, 16hr conche   875.0
# 1782                     Zotter   Satipo Pangoa region, 20hr conche   875.0
# 1783                     Zotter  Loma Los Pinos, Yacao region, D.R.   875.0
# 1784                     Zotter                              El Oro   879.0
# 1785                     Zotter                        Huiwani Coop   879.0
# 1786                     Zotter                       El Ceibo Coop   879.0
# 16                            Papua New Guinea
# 17              Trinitario           Venezuela
# 18                                        Peru
# 19                                        Peru
# 20                                        Peru
# 21                                     Bolivia
# 22                                        Peru
# 23                                        Peru
# 24                 Criollo                Peru
# 25              Trinitario                Fiji
# 26              Trinitario                Fiji
# 27              Trinitario                Fiji
# 28              Trinitario                Fiji
# 29      Forastero (Arriba)             Ecuador
# ...                    ...                 ...
# 1765            Trinitario              Belize
# 1766
# 1767   Criollo, Trinitario          Madagascar
# 1768     Nacional (Arriba)             Ecuador
# 1769            Trinitario            Trinidad
# 1770   Criollo, Trinitario            Tanzania
# 1771   Criollo, Trinitario            Tanzania
# 1772            Trinitario            Trinidad
# 1773                           Solomon Islands
# 1774
# 1775                                   Bolivia
# 1776            Trinitario    Papua New Guinea
# 1777                                   Bolivia
# 1778
# 1779                                    Panama
# 1780
# 1781      Criollo (Amarru)                Peru
# 1782      Criollo (Amarru)                Peru
# 1783                        Dominican Republic
# 1784  Forastero (Nacional)             Ecuador
# 1785   Criollo, Trinitario    Papua New Guinea
# 1786                                   Bolivia
# 1787                        Dominican Republic
# 1788             Forastero               Congo
# 1789
# 1790                                      Peru
# 1791             Forastero               Congo
# 1792             Forastero               India
# 1793                                     India
# 1794                                    Brazil
#
# [1795 rows x 9 columns]

# %% [markdown]
# Pandas alows us to index the data set ```Data``` by using the column names and row numbers as ```DF[columnname][rownumber]```
#
# For example we can find the first $10$ rows of the ```REF``` column as follows. Or return them as
# a ```np.array``` by using the ```.values``` member data.

# %%
REF10 = Data["REF"][0:10]
print(REF10, "\n")
print(REF10.values)
# Out:
# 0       NaN
# 1    1676.0
# 2    1676.0
# 3    1680.0
# 4    1704.0
# 5    1315.0
# 6    1315.0
# 7    1315.0
# 8    1319.0
# 9    1319.0
# Name: REF, dtype: float64
#
# [  nan 1676. 1676. 1680. 1704. 1315. 1315. 1315. 1319. 1319.]

# %% [markdown]
# Data will not always be simple to work with, for example try getting the "Bean Type" column.
#
# You will probably find it difficult.
#
# It turns out that the names of the columns are not so obviously converted to code.
#
# But we can use the ```.columns``` member data to get the actual column names as Python strings to save hassel.

# %%
Data.columns
# Out:
# Index(['Company \n(Maker-if known)', 'Specific Bean Origin\nor Bar Name',
#        'REF', 'Review\nDate', 'Cocoa\nPercent', 'Company\nLocation', 'Rating',
#        'Bean\nType', 'Broad Bean\nOrigin'],
#       dtype='object')

# %% [markdown]
# Notice that the "Bean Type" column is actually addressed by the Python string "Bean\nType" (recall \n means a newline in a Python string)

# %%
Data["Bean\nType"][0:10]
# Out:
# 0
# 1
# 2
# 3
# 4
# 5    Criollo
# 6
# 7    Criollo
# 8    Criollo
# 9
# Name: Bean\nType, dtype: object

# %% [markdown]
# ### Visualisation and Pre-Processing
#
# Pre-Processing is the step by which we fix any errors, missing values, or change our data (like subtracting a mean or converting date formats). This process is also known as *transforming* the raw data.
#
# See above that the "Bean Type" column has many blank values. For purposes of understanding we
# could replace all empty strings in this column by say "Unkown" or "Unknown/Mixture" or something else that our knowledge of the data suggests as pertinent.
#
# #### Missing Text Data
#
# If we run
# ```Python
# Data["Bean\nType"][0]
# ```
# which we know is empty you will  see the output
# ```Python
# '\xa0'
# ```
# You can Google this character to find it is a "No-break space" unicode character.
#
# The details don't matter but suffice it to say most text-data pre-processing involves
# getting rid of weird characters like this.
#
# Luckily we can do that with ```.replace(a,b)``` in pandas which returns a transformed dataset.
#
# We can use the ```inplace=True``` argument to do this to Data directly.

# %%
# return the transformed data, with Data unchanged
a = Data["Bean\nType"].replace('\xa0',"Unkown")
print(a[0:10])
# Data has not been modified
print("\n", Data["Bean\nType"][0:10])
# Out:
# 0     Unkown
# 1     Unkown
# 2     Unkown
# 3     Unkown
# 4     Unkown
# 5    Criollo
# 6     Unkown
# 7    Criollo
# 8    Criollo
# 9     Unkown
# Name: Bean\nType, dtype: object
#
#  0
# 1
# 2
# 3
# 4
# 5    Criollo
# 6
# 7    Criollo
# 8    Criollo
# 9
# Name: Bean\nType, dtype: object

# %%
# Data is now changed
Data["Bean\nType"].replace('\xa0',"Unkown",inplace=True)
Data
# Out:
#      Company \n(Maker-if known)   Specific Bean Origin\nor Bar Name     REF  \
# 0                      A. Morin                         Agua Grande     NaN
# 1                      A. Morin                               Kpime  1676.0
# 2                      A. Morin                              Atsane  1676.0
# 3                      A. Morin                               Akata  1680.0
# 4                      A. Morin                              Quilla  1704.0
# 5                      A. Morin                            Carenero  1315.0
# 6                      A. Morin                                Cuba  1315.0
# 7                      A. Morin                        Sur del Lago  1315.0
# 8                      A. Morin                      Puerto Cabello  1319.0
# 9                      A. Morin                             Pablino  1319.0
# 10                     A. Morin                              Panama  1011.0
# 11                     A. Morin                          Madagascar  1011.0
# 12                     A. Morin                              Brazil  1011.0
# 13                     A. Morin                            Equateur  1011.0
# 14                     A. Morin                            Colombie  1015.0
# 15                     A. Morin                            Birmanie  1015.0
# 16                     A. Morin                    Papua New Guinea  1015.0
# 17                     A. Morin                               Chuao  1015.0
# 18                     A. Morin                               Piura  1019.0
# 19                     A. Morin                Chanchamayo Province  1019.0
# 20                     A. Morin                Chanchamayo Province  1019.0
# 21                     A. Morin                             Bolivia   797.0
# 22                     A. Morin                                Peru   797.0
# 23                       Acalli             Chulucanas, El Platanal  1462.0
# 24                       Acalli                   Tumbes, Norandino  1470.0
# 25                          Adi                          Vanua Levu   705.0
# 26                          Adi                  Vanua Levu, Toto-A   705.0
# 27                          Adi                          Vanua Levu   705.0
# 28                          Adi              Vanua Levu, Ami-Ami-CA   705.0
# 29           Aequare (Gianduja)           Los Rios, Quevedo, Arriba   370.0
# ...                         ...                                 ...     ...
# 1765                      Zak's                     Belize, Batch 2  1578.0
# 1766                      Zak's                House Blend, Batch 2  1582.0
# 1767              Zart Pralinen                  Millot P., Ambanja  1820.0
# 1768              Zart Pralinen                             UNOCACE  1824.0
# 1769              Zart Pralinen                     San Juan Estate  1824.0
# 1770              Zart Pralinen      Kakao Kamili, Kilombero Valley  1824.0
# 1771              Zart Pralinen      Kakao Kamili, Kilombero Valley  1824.0
# 1772              Zart Pralinen         San Juan Estate, Gran Couva  1880.0
# 1773                     Zokoko                         Guadalcanal  1716.0
# 1788          2012            68%           Austria    3.25
# 1789          2012            58%           Austria    3.50
# 1790          2011            70%           Austria    3.75
# 1791          2011            65%           Austria    3.00
# 1792          2011            65%           Austria    3.50
# 1793          2011            62%           Austria    3.25
# 1794          2010            65%           Austria    3.00
#
#                 Bean\nType  Broad Bean\nOrigin
# 0                   Unkown            Sao Tome
# 1                   Unkown                Togo
# 2                   Unkown                Togo
# 3                   Unkown                Togo
# 4                   Unkown                Peru
# 5                  Criollo           Venezuela
# 6                   Unkown                Cuba
# 7                  Criollo           Venezuela
# 8                  Criollo           Venezuela
# 9                   Unkown                Peru
# 10                  Unkown              Panama
# 11                 Criollo          Madagascar
# 12                  Unkown              Brazil
# 13                  Unkown             Ecuador
# 14                  Unkown            Colombia
# 15                  Unkown               Burma
# 16                  Unkown    Papua New Guinea
# 17              Trinitario           Venezuela
# 18                  Unkown                Peru
# 19                  Unkown                Peru
# 20                  Unkown                Peru
# 21                  Unkown             Bolivia
# 22                  Unkown                Peru
# 23                  Unkown                Peru
# 24                 Criollo                Peru
# 25              Trinitario                Fiji
# 26              Trinitario                Fiji
# 27              Trinitario                Fiji
# 28              Trinitario                Fiji
# 29      Forastero (Arriba)             Ecuador
# ...                    ...                 ...
# 1765            Trinitario              Belize
# 1766                Unkown
# 1767   Criollo, Trinitario          Madagascar
# 1768     Nacional (Arriba)             Ecuador
# 1769            Trinitario            Trinidad
# 1770   Criollo, Trinitario            Tanzania
# 1771   Criollo, Trinitario            Tanzania
# 1772            Trinitario            Trinidad
# 1773                Unkown     Solomon Islands
# 1774                Unkown
# 1775                Unkown             Bolivia
# 1776            Trinitario    Papua New Guinea
# 1777                Unkown             Bolivia
# 1778                Unkown
# 1779                Unkown              Panama
# 1780                Unkown
# 1781      Criollo (Amarru)                Peru
# 1782      Criollo (Amarru)                Peru
# 1783                Unkown  Dominican Republic
# 1784  Forastero (Nacional)             Ecuador
# 1785   Criollo, Trinitario    Papua New Guinea
# 1786                Unkown             Bolivia
# 1787                Unkown  Dominican Republic
# 1788             Forastero               Congo
# 1789                Unkown
# 1790                Unkown                Peru
# 1791             Forastero               Congo
# 1792             Forastero               India
# 1793                Unkown               India
# 1794                Unkown              Brazil
#
# [1795 rows x 9 columns]

# %% [markdown]
# #### Missing Number Data
#
# In ```numpy``` there is a special "number" type called ```np.nan``` meaning "not-a-number". Notice we have
# such an entry in ```Data["REF"][0]```.
#
# We can use replace to get rid of these if we wish.
#
# To actually replace this value read what "REF" is. It is a value linked to
# the Review Date.
#
# The best approach would be to know the function that links these variables, the second best would
# be to "model" the function by fitting the data properly.
#
# The quickest (which we will use here) is to take the average value of all reviews with the same date (not the resolution is in years so error is introduced).
#
# We can achieve this with Boolean indexing and ```np.mean```
#
# You can inspect ```RD2016``` to see that the Review Date column does indeed have only 2016 as values.

# %%
# create an array, with True and False value scorresponding to the test x == 2016
# applied to each rows Review\nDate column
index = Data["Review\nDate"] == 2016
# lest see how many there are
print(np.sum(index))
# Boolean index to get the relevant rows
RD2016 = Data[index]
RD2016
# Out:
# 219
# 47                  Unkown                Peru
# 48                  Unkown             Ecuador
# 94                  Unkown             Bolivia
# 99              Trinitario            Trinidad
# 100                 Unkown            Tanzania
# 101             Trinitario             Vietnam
# 102                 Unkown             Ecuador
# 103                 Unkown             Ecuador
# 104                 Unkown           Guatemala
# 105                 Unkown           Nicaragua
# 106                 Unkown            Honduras
# 107                 Unkown          Costa Rica
# 108   Forastero (Nacional)                Peru
# 109                 Unkown  Dominican Republic
# 110                 Unkown                Fiji
# 111                 Unkown             Vietnam
# 138             Trinitario            Tanzania
# 157                 Unkown   Domincan Republic
# 158                 Unkown              Brazil
# 159                 Unkown             Ecuador
# 162                 Unkown              Brazil
# 163                 Unkown   Domincan Republic
# 164                 Unkown             Ecuador
# 165                 Unkown             Ecuador
# 170    Criollo, Trinitario            Tanzania
# 171                 Unkown             Bolivia
# ...                    ...                 ...
# 1568                Unkown   Domincan Republic
# 1569                Unkown             Ecuador
# 1570                Unkown          Madagascar
# 1589   Criollo, Trinitario                Peru
# 1590   Criollo, Trinitario                Peru
# 1591                Unkown           Venezuela
# 1592                Unkown           Venezuela
# 1617            Trinitario            Suriname
# 1622             Forastero         West Africa
# 1661      Trinitario, TCGA              Belize
# 1675               Criollo                Peru
# 1679            Trinitario          Madagascar
# 1680                Unkown            Tanzania
# 1729                Unkown                Peru
# 1730                Unkown           Venezuela
# 1731                Unkown   Domincan Republic
# 1732            Trinitario  Dominican Republic
# 1733                Unkown                Peru
# 1739                Unkown            Colombia
# 1747               Criollo           Venezuela
# 1748                Unkown             Bolivia
# 1749                Unkown               Ghana
# 1767   Criollo, Trinitario          Madagascar
# 1768     Nacional (Arriba)             Ecuador
# 1769            Trinitario            Trinidad
# 1770   Criollo, Trinitario            Tanzania
# 1771   Criollo, Trinitario            Tanzania
# 1772            Trinitario            Trinidad
# 1773                Unkown     Solomon Islands
# 1774                Unkown
#
# [219 rows x 9 columns]

# %% [markdown]
# #### Use the ```np.mean``` function replace the single nan in ```Data["REF"]``` with the mean of ```RD2016["REF"]```

# %% [markdown]
# To examine our replacement statistics we can check the ```RD2016["REF"]``` standard deviation and
# standard error as below. This assumes an identical distribution in ```REF``` which we know is probably wrong
# due to the resolution of the ```Review Date```.
#
# It does tell us that these values are quite high, so in future modelling we might want
# to remove row $0$ entirely, or since it's $1$ in $1794$ we could just accept the error.

# %%
print("Standard Deviation = ",np.std(RD2016["REF"]))
print("Standard Error of the Mean = ",np.std(RD2016["REF"]) / np.sqrt(RD2016.shape[0]))
# Out:
# Standard Deviation =  63.31196582331621
# Standard Error of the Mean =  4.278226180676555

# %% [markdown]
# #### Visualising the Numerical Data with ```pairplot```
#
# The package seaborn has a particulalry good function for graphically summarising the numerical
# data in a ```pandas.DataFrame```.
#
# Below we use ```seaborn.pairplot()``` to plot the *correlogram* for our data. This is a matrix of
# plots with histograms on the diagonal and $x-y$ series in other squares.
#
# Observe the plots individually and notice the following:
#
# - There are no "Cocoa Percent" plots
# - The REF-Review Date data shows that for each year there are multiple REF values, this is the resolution problem
# - The Review Date histogram shows a skew to later years which will bias our data set in time

# %%
Data["REF"][0] = 1
seaborn.pairplot(Data)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### Advanced Data Transformation: Lambda Functions
#
# Upon inspection of ```Data["Cocoa\nPercent"][0]``` you wil see they are strings.
#
# We can replace them with floats by using the ```.apply``` method from pandas along
# with something called a *lambda function*.
#
# Lambdas (or anonymous function) are fnuction that are passed as arguments with no name, i.e quick to
# write functions that can be thrown awaya without care. There use will become clear soon.
#
# A Lambda is written in Python as below.
#
# We use the keyword
# ```Python
# lambda
# ```
# And a list of arguments followed by ```:```. Then the function body is written (typically on one line).
#
# We can assign lambda functions to variables or simple pass them as arguments.

# %%
l1 = lambda x: x^2
l2 = lambda x,y: x+y
print("l1(4) = ",l1(4))
print("l2(3,5) = ",l2(3,5))
# Out:
# l1(4) =  6
# l2(3,5) =  8

# %% [markdown]
# To replace strings such as "67%" with decimals like $0.67$ we need to remove the "%", convert the string to a
# number and divide through $100$ to form the percentage.
#
# Below we implement a lambda function that does just that.
#
# ```StoD``` takes a string ```s```, uses the split method to break off the parts
# ```Python
# "67%".split("%") # = ["67" "%"]
# ```
# We take the first part (the number) perform a *type cast* (conversion of one type to another) to convert
# the string number to an actual float. Finally we divide by $100.0$ to get our decimal percentage.

# %%
StoD = lambda s: float(s.split("%")[0]) / 100.0
StoD("67%")
# Out:
# 0.67

# %% [markdown]
# If we pass this lambda expression directly into apply we can convert all the string percentages to
# decimal values!
#
# Notice we just write the lambda within ```.apply()``` a truely throw away function!

# %%
Data["Cocoa\nPercent"] = Data["Cocoa\nPercent"].apply(lambda s: float(s.split("%")[0]) / 100.0);
Data
# Out:
#      Company \n(Maker-if known)   Specific Bean Origin\nor Bar Name     REF  \
# 0                      A. Morin                         Agua Grande     1.0
# 1                      A. Morin                               Kpime  1676.0
# 2                      A. Morin                              Atsane  1676.0
# 3                      A. Morin                               Akata  1680.0
# 4                      A. Morin                              Quilla  1704.0
# 5                      A. Morin                            Carenero  1315.0
# 6                      A. Morin                                Cuba  1315.0
# 7                      A. Morin                        Sur del Lago  1315.0
# 8                      A. Morin                      Puerto Cabello  1319.0
# 9                      A. Morin                             Pablino  1319.0
# 10                     A. Morin                              Panama  1011.0
# 11                     A. Morin                          Madagascar  1011.0
# 12                     A. Morin                              Brazil  1011.0
# 13                     A. Morin                            Equateur  1011.0
# 14                     A. Morin                            Colombie  1015.0
# 15                     A. Morin                            Birmanie  1015.0
# 16                     A. Morin                    Papua New Guinea  1015.0
# 17                     A. Morin                               Chuao  1015.0
# 18                     A. Morin                               Piura  1019.0
# 19                     A. Morin                Chanchamayo Province  1019.0
# 20                     A. Morin                Chanchamayo Province  1019.0
# 21                     A. Morin                             Bolivia   797.0
# 22                     A. Morin                                Peru   797.0
# 23                       Acalli             Chulucanas, El Platanal  1462.0
# 24                       Acalli                   Tumbes, Norandino  1470.0
# 25                          Adi                          Vanua Levu   705.0
# 26                          Adi                  Vanua Levu, Toto-A   705.0
# 27                          Adi                          Vanua Levu   705.0
# 28                          Adi              Vanua Levu, Ami-Ami-CA   705.0
# 29           Aequare (Gianduja)           Los Rios, Quevedo, Arriba   370.0
# 1770          2016            0.85           Austria    3.00
# 1771          2016            0.70           Austria    3.50
# 1772          2016            0.78           Austria    3.50
# 1773          2016            0.78         Australia    3.75
# 1774          2016            0.65         Australia    3.25
# 1775          2011            0.68         Australia    3.50
# 1776          2011            0.66         Australia    3.50
# 1777          2011            0.72         Australia    3.75
# 1778          2014            0.80           Austria    2.75
# 1779          2012            0.72           Austria    3.50
# 1780          2012            0.65           Austria    3.50
# 1781          2012            0.70           Austria    3.00
# 1782          2012            0.70           Austria    3.50
# 1783          2012            0.62           Austria    3.75
# 1784          2012            0.75           Austria    3.00
# 1785          2012            0.75           Austria    3.00
# 1786          2012            0.90           Austria    3.25
# 1787          2012            0.70           Austria    3.75
# 1788          2012            0.68           Austria    3.25
# 1789          2012            0.58           Austria    3.50
# 1790          2011            0.70           Austria    3.75
# 1791          2011            0.65           Austria    3.00
# 1792          2011            0.65           Austria    3.50
# 1793          2011            0.62           Austria    3.25
# 1794          2010            0.65           Austria    3.00
#
#                 Bean\nType  Broad Bean\nOrigin
# 0                   Unkown            Sao Tome
# 1                   Unkown                Togo
# 2                   Unkown                Togo
# 3                   Unkown                Togo
# 4                   Unkown                Peru
# 5                  Criollo           Venezuela
# 6                   Unkown                Cuba
# 7                  Criollo           Venezuela
# 8                  Criollo           Venezuela
# 9                   Unkown                Peru
# 10                  Unkown              Panama
# 11                 Criollo          Madagascar
# 12                  Unkown              Brazil
# 13                  Unkown             Ecuador
# 14                  Unkown            Colombia
# 15                  Unkown               Burma
# 16                  Unkown    Papua New Guinea
# 17              Trinitario           Venezuela
# 18                  Unkown                Peru
# 19                  Unkown                Peru
# 20                  Unkown                Peru
# 21                  Unkown             Bolivia
# 22                  Unkown                Peru
# 23                  Unkown                Peru
# 24                 Criollo                Peru
# 25              Trinitario                Fiji
# 26              Trinitario                Fiji
# 27              Trinitario                Fiji
# 28              Trinitario                Fiji
# 29      Forastero (Arriba)             Ecuador
# ...                    ...                 ...
# 1765            Trinitario              Belize
# 1766                Unkown
# 1767   Criollo, Trinitario          Madagascar
# 1768     Nacional (Arriba)             Ecuador
# 1769            Trinitario            Trinidad
# 1770   Criollo, Trinitario            Tanzania
# 1771   Criollo, Trinitario            Tanzania
# 1772            Trinitario            Trinidad
# 1773                Unkown     Solomon Islands
# 1774                Unkown
# 1775                Unkown             Bolivia
# 1776            Trinitario    Papua New Guinea
# 1777                Unkown             Bolivia
# 1778                Unkown
# 1779                Unkown              Panama
# 1780                Unkown
# 1781      Criollo (Amarru)                Peru
# 1782      Criollo (Amarru)                Peru
# 1783                Unkown  Dominican Republic
# 1784  Forastero (Nacional)             Ecuador
# 1785   Criollo, Trinitario    Papua New Guinea
# 1786                Unkown             Bolivia
# 1787                Unkown  Dominican Republic
# 1788             Forastero               Congo
# 1789                Unkown
# 1790                Unkown                Peru
# 1791             Forastero               Congo
# 1792             Forastero               India
# 1793                Unkown               India
# 1794                Unkown              Brazil
#
# [1795 rows x 9 columns]

# %% [markdown]
# Now we can view the Cocoa Percent in the pairplot

# %%
seaborn.pairplot(Data)
